# %%
import pandas as pd
music = pd.read_csv("charts.csv")

# %%
music.shape
# Out:
# (26173514, 9)

# %%
music[music['streams'] > 2000000]
# Out:
#                                                       title  rank        date  \
# 3234                                                Starboy     1  2017-01-01
# 3235                                                 Closer     2  2017-01-01
# 3236                                        Let Me Love You     3  2017-01-01
# 3237                Rockabye (feat. Sean Paul & Anne-Marie)     4  2017-01-01
# 3238                                              One Dance     5  2017-01-01
# ...                                                     ...   ...         ...
# 25251443                                           Stir Fry    15  2018-01-31
# 25251444                                           Sick Boy    16  2018-01-31
# 25251445  Let Me Go (with Alesso, Florida Georgia Line &...    17  2018-01-31
# 25251446                                       I Fall Apart    18  2018-01-31
# 25275673                                         God's Plan     1  2018-01-31
#
# ...

# %%
music.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26173514 entries, 0 to 26173513
# Data columns (total 9 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   title    object
#  1   rank     int64
#  2   date     object
#  3   artist   object
#  4   url      object
#  5   region   object
#  6   chart    object
#  7   trend    object
#  8   streams  float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 1.8+ GB

# %%
# music.groupby('chart')['title'].value_counts()

# %%
music[music['title'] == 'Starboy']
# Out:
#             title  rank        date                 artist  \
# 28        Starboy    29  2017-01-01  The Weeknd, Daft Punk
# 201       Starboy     1  2017-01-01  The Weeknd, Daft Punk
# 408       Starboy     7  2017-01-01  The Weeknd, Daft Punk
# 605       Starboy     3  2017-01-01  The Weeknd, Daft Punk
# 819       Starboy    17  2017-01-01  The Weeknd, Daft Punk
# ...           ...   ...         ...                    ...
# 25606434  Starboy    37  2021-02-11  The Weeknd, Daft Punk
# 25646367  Starboy    31  2021-02-12  The Weeknd, Daft Punk
# 25666554  Starboy    32  2021-02-13  The Weeknd, Daft Punk
# 25710113  Starboy    33  2021-02-14  The Weeknd, Daft Punk
# 26017226  Starboy    37  2021-02-28  The Weeknd, Daft Punk
#
#                                                         url       region  \
# 28        https://open.spotify.com/track/5aAx2yezTd8zXrk...    Argentina
# 201       https://open.spotify.com/track/5aAx2yezTd8zXrk...    Australia
# ...

# %%
# music.groupby('title').value_counts()

# %%
# music.head()

# %%
music.tail()
# Out:
#                                   title  rank        date  \
# 26173509                            BYE    46  2021-07-31
# 26173510                        Pillars    47  2021-07-31
# 26173511                   Gái Độc Thân    48  2021-07-31
# 26173512  Renegade (feat. Taylor Swift)    49  2021-07-31
# 26173513                Letter to Jarad    50  2021-07-31
#
#                              artist  \
# 26173509                      Jaden
# 26173510                     My Anh
# 26173511                      Tlinh
# 26173512            Big Red Machine
# 26173513  LRN Slime, Shiloh Dynasty
#
#                                                         url   region    chart  \
# 26173509  https://open.spotify.com/track/3OUyyDN7EZrL7i0...  Vietnam  viral50
# 26173510  https://open.spotify.com/track/6eky30oFiQbHUAT...  Vietnam  viral50
# 26173511  https://open.spotify.com/track/2klsSb2iTfgDh95...  Vietnam  viral50
# ...

# %%
music.isnull().sum()
# Out:
# title           11
# rank             0
# date             0
# artist          18
# url              0
# region           0
# chart            0
# trend            0
# streams    5851610
# dtype: int64

# %%
# subset.to_csv('subset.csv', index=False)

# %%
music['streams'].median()
# Out:
# np.float64(9565.0)

# %%
# music['price'] = music['streams'].fillna(music['streams'].median())
# music.isnull().sum()

# %%
music.loc[music['artist'].isnull()]
# Out:
#             title  rank        date artist  \
# 20596664  NO GOOD    10  2020-07-13    NaN
# 20616457  NO GOOD    10  2020-07-14    NaN
# 20640094  NO GOOD    10  2020-07-15    NaN
# 20661724  NO GOOD    10  2020-07-16    NaN
# 20677645  NO GOOD    10  2020-07-17    NaN
# 20705363  NO GOOD    10  2020-07-18    NaN
# 20726697  NO GOOD    10  2020-07-19    NaN
# 20748638  NO GOOD    13  2020-07-20    NaN
# 20788975  NO GOOD    14  2020-07-21    NaN
# 20833982  NO GOOD    19  2020-07-22    NaN
# 20865824  NO GOOD    23  2020-07-23    NaN
# 20887012  NO GOOD    20  2020-07-24    NaN
# 20903930  NO GOOD    21  2020-07-25    NaN
# 20932541  NO GOOD    24  2020-07-26    NaN
# 20960407  NO GOOD    36  2020-07-27    NaN
# 20992837  NO GOOD    43  2020-07-28    NaN
# 21026109  NO GOOD    40  2020-07-29    NaN
# 21057585  NO GOOD    46  2020-07-30    NaN
#
#                                                         url region    chart  \
# ...

# %%
music.loc[music['title'].isnull()]
# Out:
#          title  rank        date artist  \
# 7305002    NaN   120  2019-06-24  Nissy
# 7401555    NaN   167  2019-06-25  Nissy
# 7479161    NaN   128  2019-06-26  Nissy
# 7563494    NaN   164  2019-06-27  Nissy
# 7670140    NaN   174  2019-06-28  Nissy
# 7772268    NaN   188  2019-06-29  Nissy
# 7879888    NaN   169  2019-06-30  Nissy
# 14391788   NaN    38  2019-07-15  Nissy
# 14481594   NaN    48  2019-07-16  Nissy
# 14768101   NaN    46  2019-07-17  Nissy
# 14773425   NaN    48  2019-07-18  Nissy
#
#                                                         url region    chart  \
# 7305002   https://open.spotify.com/track/4cP6KmNvTFkLHZo...  Japan   top200
# 7401555   https://open.spotify.com/track/4cP6KmNvTFkLHZo...  Japan   top200
# 7479161   https://open.spotify.com/track/4cP6KmNvTFkLHZo...  Japan   top200
# 7563494   https://open.spotify.com/track/4cP6KmNvTFkLHZo...  Japan   top200
# 7670140   https://open.spotify.com/track/4cP6KmNvTFkLHZo...  Japan   top200
# ...

# %%
music[(music['title'] == 'Hello') & (music['artist'] == 'Adele') & (music['region'] == 'Global')].sort_values(by='date')
# Out:
#           title  rank        date artist  \
# 3366      Hello   132  2017-01-01  Adele
# 15442     Hello   123  2017-01-02  Adele
# 39905     Hello   125  2017-01-03  Adele
# 83699     Hello   127  2017-01-04  Adele
# 143711    Hello   124  2017-01-05  Adele
# ...         ...   ...         ...    ...
# 23388948  Hello   141  2021-10-19  Adele
# 23469929  Hello   152  2021-10-20  Adele
# 23444557  Hello   165  2021-10-21  Adele
# 23590606  Hello   192  2021-10-22  Adele
# 23831760  Hello   199  2021-10-25  Adele
#
#                                                         url  region   chart  \
# 3366      https://open.spotify.com/track/4sPmO7WMQUAf45k...  Global  top200
# 15442     https://open.spotify.com/track/4sPmO7WMQUAf45k...  Global  top200
# 39905     https://open.spotify.com/track/4sPmO7WMQUAf45k...  Global  top200
# 83699     https://open.spotify.com/track/4sPmO7WMQUAf45k...  Global  top200
# 143711    https://open.spotify.com/track/4sPmO7WMQUAf45k...  Global  top200
# ...

# %%
import pandas as pd
music_V2 = pd.read_csv("music.csv")

# %%
music_V2.shape
# Out:
# (26173485, 9)

# %%
music_V2['streams'].sum()
# Out:
# np.float64(1178985490738.0)

# %%
music_V2["artist"].nunique()
# Out:
# 96156
