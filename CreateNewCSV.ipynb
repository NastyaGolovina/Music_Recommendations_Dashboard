# %%
import pandas as pd
music = pd.read_csv("charts.csv")

# %%
music.isnull().sum()
# Out:
# title           11
# rank             0
# date             0
# artist          18
# url              0
# region           0
# chart            0
# trend            0
# streams    5851610
# dtype: int64

# %%
music['streams'].median()
# Out:
# np.float64(9565.0)

# %%
music['streams'] = music['streams'].fillna(music['streams'].median())
music.isnull().sum()
# Out:
# title      11
# rank        0
# date        0
# artist     18
# url         0
# region      0
# chart       0
# trend       0
# streams     0
# dtype: int64

# %%
music.dropna(inplace=True)
music.isnull().sum()
# Out:
# title      0
# rank       0
# date       0
# artist     0
# url        0
# region     0
# chart      0
# trend      0
# streams    0
# dtype: int64

# %%
music.to_csv('music_v0.csv', index=False)

# %%
# music['artist'].drop_duplicates().to_csv('artists.csv', index=False)

# %%
# Out:
# 96156
