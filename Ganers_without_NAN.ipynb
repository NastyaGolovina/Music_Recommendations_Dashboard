# %%
import pandas as pd
music_V2 = pd.read_csv("artists_merged_clean_NAN_to_pop.csv")

music_V2.isnull().sum()
# Out:
# artist    0
# genre     0
# dtype: int64

# %%
import pandas as pd

genres = pd.read_csv("artists_merged.csv")

# Без inplace — новый синтаксис
genres["genre"] = genres["genre"].fillna("pop")

genres.to_csv("artists_merged_clean_NAN_to_pop.csv", index=False)

print("Готово! Осталось NaN:", genres["genre"].isnull().sum())
# Out:
# Готово! Осталось NaN: 0
